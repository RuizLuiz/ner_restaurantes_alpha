# %%
import matplotlib.pyplot as plt
import numpy as np

# Definindo os vetores de dados
desbalanceados = np.array([92.37, 90.37, 87.83, 65.88, 89.63, 83.29, 76.66])
balanceados = np.array([87.14, 84.52, 83.79, 73.49, 89.02, 89.91, 73.94])

# Definindo as posições das barras no eixo x
posicoes = np.arange(len(desbalanceados))

# Criando o gráfico de barras
plt.bar(posicoes, desbalanceados, width=0.4, label='Desbalanceados', color='#87CEFA')
plt.bar(posicoes+0.4, balanceados, width=0.4, label='Balanceados', color='#1E3A8A')

# Adicionando rótulos aos eixos e ao gráfico
plt.xlabel('Classes')
plt.ylabel('Porcentagem')
plt.title('Comparação de dados (Precisão)')
plt.xticks(posicoes+0.2, ['Serviço', 'Comida', 'Ambiente', 'Localização', 'Geral', 'Bebida', 'Preço'], rotation=30, ha='right')
plt.legend()

# Ajustando a escala do eixo y
plt.ylim(0, 120)

# Exibindo o gráfico
plt.show()

# Definindo os vetores de dados
desbalanceados = np.array([87.87, 84.30, 84.68, 60.52, 89.69, 71.59, 75.82])
balanceados = np.array([85.61, 82.69, 82.69, 60.79, 93.39, 80.13, 69.56])

# Definindo as posições das barras no eixo x
posicoes = np.arange(len(desbalanceados))

# Criando o gráfico de barras
plt.bar(posicoes, desbalanceados, width=0.4, label='Desbalanceados', color='#87CEFA')
plt.bar(posicoes+0.4, balanceados, width=0.4, label='Balanceados', color='#1E3A8A')

# Adicionando rótulos aos eixos e ao gráfico
plt.xlabel('Classes')
plt.ylabel('Porcentagem')
plt.title('Comparação de dados (Revocação)')
plt.xticks(posicoes+0.2, ['Serviço', 'Comida', 'Ambiente', 'Localização', 'Geral', 'Bebida', 'Preço'], rotation=30, ha='right')
plt.legend()

# Ajustando a escala do eixo y
plt.ylim(0, 120)

# Exibindo o gráfico
plt.show()

# Definindo os vetores de dados
desbalanceados = np.array([0.90, 0.87, 0.86, 0.60, 0.89, 0.75, 0.75])
balanceados = np.array([0.86, 0.83, 0.83, 0.66, 0.91, 0.84, 0.71])

# Definindo as posições das barras no eixo x
posicoes = np.arange(len(desbalanceados))

# Criando o gráfico de barras
plt.bar(posicoes, desbalanceados, width=0.4, label='Desbalanceados', color='#87CEFA')
plt.bar(posicoes+0.4, balanceados, width=0.4, label='Balanceados', color='#1E3A8A')

# Adicionando rótulos aos eixos e ao gráfico
plt.xlabel('Classes')
plt.ylabel('Proporção')
plt.title('Comparação de dados (F1-Score)')
plt.xticks(posicoes+0.2, ['Serviço', 'Comida', 'Ambiente', 'Localização', 'Geral', 'Bebida', 'Preço'], rotation=30, ha='right')
plt.legend()

# Ajustando a escala do eixo y
plt.ylim(0, 1.2)

# Exibindo o gráfico
plt.show()

# Definindo os vetores de dados
desbalanceados = np.array([0.84, 0.74])
balanceados = np.array([0.73, 0.69])

# Definindo as posições das barras no eixo x
posicoes = np.arange(len(desbalanceados))

# Criando o gráfico de barras
plt.bar(posicoes, desbalanceados, width=0.4, label='(RUIZ, 2023)', color='#87CEFA')
plt.bar(posicoes+0.4, balanceados, width=0.4, label='(CHAVES, 2021)', color='#1E3A8A')

# Adicionando rótulos aos eixos e ao gráfico
plt.xlabel('Classes')
plt.ylabel('Proporção')
plt.title('Comparação de dados (F1-Score)')
plt.xticks(posicoes+0.2, ['Maioritárias', 'Minoritárias'], rotation=30, ha='right')
plt.legend()

# Ajustando a escala do eixo y
plt.ylim(0, 1.2)

# Exibindo o gráfico
plt.show()

#desbalanceados
# \textit{Serviço:} & 92.37\% &  87.87\% & 0.90\\
# \textit{Comida:} & 90.37\% &  84.30\% & 0.87\\
# \textit{Ambiente:} & 87.83\% &  84.68\% & 0.86\\
# \textit{Localização:} & 65.88\% &  60.52\% & 0.60\\
# \textit{Geral:} & 89.63\% &  89.69\% & 0.89\\
# \textit{Bebida:} & 83.29\% &  71.59\% & 0.75\\
# \textit{Preço:} & 76.66\% &  75.82\% & 0.75\\

#balanceados
# \textit{Serviço:} & 87.14\% &  85.61\% & 0.86\\
# \textit{Comida:} & 84.52\% &  82.69\% & 0.83\\
# \textit{Ambiente:} & 83.79\% &  82.69\% & 0.83\\
# \textit{Localização:} & 73.49\% &  60.79\% & 0.66\\
# \textit{Geral:} & 89.02\% &  93.39\% & 0.91\\
# \textit{Bebida:} & 89.91\% &  80.13\% & 0.84\\
# \textit{Preço:} & 73.94\% &  69.56\% & 0.71\\

# %%
a = "('Comentário do usuário', {'entities': [(início_entidade, fim_entidade, 'classe_entidade'), (início_entidade, fim_entidade, 'classe_entidade'),...]})"
a
# Out:
# "('Comentário do usuário', {'entities': [(início_entidade, fim_entidade, 'classe_entidade'), (início_entidade, fim_entidade, 'classe_entidade'),...]})"

# %%
a = "('Um dos melhores restaurantes de Salvador sem duvida. A fila de espera vale a pena. Comida boa, preço relativamente bom. Atendimento perfeito.', {'entities': [(16, 28, 'GERAL'), (83, 89, 'COMIDA'), (120, 131, 'SERVIÇO'), (95, 100, 'PREÇO'), (32, 40, 'LOCALIZAÇÃO')]})"
a
# Out:
# "('Um dos melhores restaurantes de Salvador sem duvida. A fila de espera vale a pena. Comida boa, preço relativamente bom. Atendimento perfeito.', {'entities': [(16, 28, 'GERAL'), (83, 89, 'COMIDA'), (120, 131, 'SERVIÇO'), (95, 100, 'PREÇO'), (32, 40, 'LOCALIZAÇÃO')]})"

# %%
from sklearn.model_selection import (
    TimeSeriesSplit,
    KFold,
    ShuffleSplit,
    StratifiedKFold,
    GroupShuffleSplit,
    GroupKFold,
    StratifiedShuffleSplit,
    StratifiedGroupKFold,
)
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

rng = np.random.RandomState(1338)
cmap_data = plt.cm.Paired
cmap_cv = plt.cm.coolwarm
n_splits = 5

# %%
# Generate the class/group data
n_points = 500
X = rng.randn(500, 10)

percentiles_classes = [0.1, 0.3, 0.6]
y = np.hstack([[ii] * int(500 * perc) for ii, perc in enumerate(percentiles_classes)])

# Generate uneven groups
group_prior = rng.dirichlet([2] * 10)
groups = np.repeat(np.arange(10), rng.multinomial(500, group_prior))


def visualize_groups(classes, groups, name):
    # Visualize dataset groups
    fig, ax = plt.subplots()
    ax.scatter(
        range(len(groups)),
        [0.5] * len(groups),
        c=groups,
        marker="_",
        lw=50,
        cmap=cmap_data,
    )
    ax.scatter(
        range(len(groups)),
        [3.5] * len(groups),
        c=classes,
        marker="_",
        lw=50,
        cmap=cmap_data,
    )
    ax.set(
        ylim=[-1, 5],
        yticks=[0.5, 3.5],
        yticklabels=["Data\ngroup", "Data\nclass"],
        xlabel="Sample index",
    )


visualize_groups(y, groups, "no groups")

# %%
def plot_cv_indices(cv, X, y, group, ax, n_splits, lw=10):
    """Create a sample plot for indices of a cross-validation object."""

    # Generate the training/testing visualizations for each CV split
    for ii, (tr, tt) in enumerate(cv.split(X=X, y=y, groups=group)):
        # Fill in indices with the training/test groups
        indices = np.array([np.nan] * len(X))
        indices[tt] = 1
        indices[tr] = 0

        # Visualize the results
        ax.scatter(
            range(len(indices)),
            [ii + 0.5] * len(indices),
            c=indices,
            marker="_",
            lw=lw,
            cmap=cmap_cv,
            vmin=-0.2,
            vmax=1.2,
        )

    # # Plot the data classes and groups at the end
    # ax.scatter(
    #     range(len(X)), [ii + 1.5] * len(X), c=y, marker="_", lw=lw, cmap=cmap_data
    # )

    # ax.scatter(
    #     range(len(X)), [ii + 2.5] * len(X), c=group, marker="_", lw=lw, cmap=cmap_data
    # )

    # Formatting
    yticklabels = list(range(n_splits)) #+ ["class", "group"]
    ax.set(
        yticks=np.arange(n_splits) + 0.5,
        yticklabels=yticklabels,
        xlabel="Número de comentários",
        ylabel="Iteração",
        ylim=[n_splits, -0.2],
        xlim=[0, 500],
    )
    ax.set_title("{}".format(type(cv).__name__), fontsize=15)
    return ax

# %%
fig, ax = plt.subplots()
cv = KFold(n_splits)
plot_cv_indices(cv, X, y, groups, ax, n_splits)
# Out:
# <AxesSubplot:title={'center':'KFold'}, xlabel='Número de comentários', ylabel='Iteração'>

# %% [markdown]
# # NER

# %%
# !python -m spacy info
# !pip install -U spacy 
# !python -m spacy download pt_core_news_lg
# !pip install spacy-annotator
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-18 19:03:09.019029: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-18 19:03:11.301098: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
import pandas as pd
import numpy as np
import spacy 
from spacy import displacy
#import spacy_annotator as spa
from pprint import pprint
from spacy.tokens import DocBin
from spacy.scorer import Scorer
import ast
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
with open('drive/MyDrive/treino_spacy/dados-tripadvisor.csv', encoding="utf-8") as f:
    df2 = pd.read_csv(f)
df2
# Out:
#                 nomeRestaurante  curtidas  rating dataVisita dataPublicacao  \
# 0         Coco Bambu Flamboyant         0       2   2016-4-1      2016-4-25
# 1         Coco Bambu Flamboyant         0       3   2016-1-1      2016-4-25
# 2         Coco Bambu Flamboyant         0       5   2016-4-1      2016-4-25
# 3         Coco Bambu Flamboyant         0       5  2015-12-1      2016-4-25
# 4         Coco Bambu Flamboyant         0       4   2016-2-1      2016-4-25
# ...                         ...       ...     ...        ...            ...
# 189559  Coco Bambu - Dom Pastel         0       5   2018-4-1      2018-4-13
# 189560  Coco Bambu - Dom Pastel         0       4   2018-4-1      2018-4-13
# 189561  Coco Bambu - Dom Pastel         0       5   2018-4-1      2018-4-13
# 189562  Coco Bambu - Dom Pastel         1       5   2018-4-1      2018-4-13
# 189563  Coco Bambu - Dom Pastel         0       5   2018-4-1      2018-4-13
#
# ...

# %%
#df = df.sample(300)

#df = df['comentario'].sample(300)
#df = pd.DataFrame({'comentario': df})

#df['comentario'] = df['comentario'].str.replace(r'[^\w\s]+', '')

#df["comentario"] = df["comentario"].str.lower()
#df

#df.to_csv('random_500_comments.csv')
df

# %%
with open('/content/drive/MyDrive/treino_spacy/random_500_comments.csv', encoding="utf-8") as f:
    df = pd.read_csv(f)
df.drop_duplicates()

# %%
with open('/content/drive/MyDrive/treino_spacy/random_500_comments.csv', encoding="utf-8") as f:
    df = pd.read_csv(f)
df2 = df[450:500]
df2
df2.index = np.arange(0, len(df2))

# %%
nlp = spacy.load("pt_core_news_lg")

# %%
annotator = spa.Annotator(labels=["AMBIENTE","GERAL","COMIDA","BEBIDA","SERVIÇO","PREÇO","LOCALIZAÇÃO"],model=nlp)

# %%
df_labels = annotator.annotate(df=df2,col_text='comentario')
# Out:
# HTML(value='-1 examples annotated, 51 examples left')
# Text(value='', description='AMBIENTE', layout=Layout(width='auto'), placeholder='ent one, ent two, ent three')
# Text(value='', description='GERAL', layout=Layout(width='auto'), placeholder='ent one, ent two, ent three')
# Text(value='', description='COMIDA', layout=Layout(width='auto'), placeholder='ent one, ent two, ent three')
# Text(value='', description='BEBIDA', layout=Layout(width='auto'), placeholder='ent one, ent two, ent three')
# Text(value='', description='SERVIÇO', layout=Layout(width='auto'), placeholder='ent one, ent two, ent three')
# Text(value='', description='PREÇO', layout=Layout(width='auto'), placeholder='ent one, ent two, ent three')
# Text(value='', description='LOCALIZAÇÃO', layout=Layout(width='auto'), placeholder='ent one, ent two, ent thre…
# ...
# Output()

# %%
df_labels.to_csv('/content/drive/MyDrive/treino_spacy/450_500_data_annotation_for_named_entity_recognition.csv',index=False)
df_labels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-49b015e79a98> in <module>
# ----> 1 df_labels.to_csv('/content/drive/MyDrive/treino_spacy/450_500_data_annotation_for_named_entity_recognition.csv',index=False)
#       2 df_labels
#
# NameError: name 'df_labels' is not defined

# %%
with open('/content/drive/MyDrive/treino_spacy/0_305_data_annotation_for_named_entity_recognition.csv', encoding="utf-8") as f:
    df = pd.read_csv(f)

# %%
df = df[['comentario', 'annotations']]
df
# Out:
#                                             comentario  \
# 0    Excelente localização, ambiente agradável, lag...
# 1    Achei o atendimento um pouco contraditório, a ...
# 2    Estivemos no Coco Bambu dia 21/01/2019 para co...
# 3    Excelente comida a atendimento do garçom Jarba...
# 4    A comida do Coco Bambu é sempre sensacional! C...
# ..                                                 ...
# 300  Apple Inc. é uma empresa multinacional norte-a...
# 301                             Maçã em inglês é apple
# 302  Gostei muito da visita ao Coco Bambu, a recepç...
# 303                          Nossa, que jantar gostoso
# 304                      Nossa, que jantar maravilhoso
#
#                                            annotations
# 0    ('Excelente localização, ambiente agradável, l...
# 1    ('Achei o atendimento um pouco contraditório, ...
# 2    ('Estivemos no Coco Bambu dia 21/01/2019 para ...
# 3    ('Excelente comida a atendimento do garçom Jar...
# ...

# %%
df['annotations'] = df['annotations'].apply(ast.literal_eval)

# %%
df
# Out:
#                                             comentario  \
# 0    Excelente localização, ambiente agradável, lag...
# 1    Achei o atendimento um pouco contraditório, a ...
# 2    Estivemos no Coco Bambu dia 21/01/2019 para co...
# 3    Excelente comida a atendimento do garçom Jarba...
# 4    A comida do Coco Bambu é sempre sensacional! C...
# ..                                                 ...
# 300  Apple Inc. é uma empresa multinacional norte-a...
# 301                             Maçã em inglês é apple
# 302  Gostei muito da visita ao Coco Bambu, a recepç...
# 303                          Nossa, que jantar gostoso
# 304                      Nossa, que jantar maravilhoso
#
#                                            annotations
# 0    (Excelente localização, ambiente agradável, la...
# 1    (Achei o atendimento um pouco contraditório, a...
# 2    (Estivemos no Coco Bambu dia 21/01/2019 para c...
# 3    (Excelente comida a atendimento do garçom Jarb...
# ...

# %%
# teste dos 5 folds

from sklearn.model_selection import KFold

data = df['annotations'].tolist()

kf = KFold(n_splits=5)

for train_index, test_index in kf.split(data):
    train_data = []
    for i in train_index:
        train_data.append(data[i])

    test_data = []
    for i in test_index:
        test_data.append(data[i])

    print(test_data[59])
# Out:
# ('Muito gostosa a comida, atendimento impecável, muito confortável. Sempre tem algumas promoções. Vale muito a pena conhecer.', {'entities': [(16, 22, 'COMIDA'), (24, 35, 'SERVIÇO'), (85, 94, 'PREÇO')]})
# ('O Rei do Trip, garçom Marlon. Excelente atendimento!!! Prato e sobremesa deliciosos. Com surpresa no final! Parabéns Coco Bambu por estar em 1° no trip!!', {'entities': [(117, 127, 'GERAL'), (55, 60, 'COMIDA'), (63, 72, 'COMIDA'), (15, 28, 'SERVIÇO'), (40, 51, 'SERVIÇO')]})
# ('Lugar agradável,  serviço impecável,  fomos atendidas pelo Maia, muito simpático,  sempre atento às nossas solicitações. Os pratos são super bem servidos e uma delícia.', {'entities': [(0, 5, 'GERAL'), (124, 130, 'COMIDA'), (18, 25, 'SERVIÇO'), (59, 63, 'SERVIÇO')]})
# ('Atendimento  do Garcon Guilherme excelente. Prato muito bem servido: Camarão Internacional, delicioso👏👏', {'entities': [(44, 49, 'COMIDA'), (69, 90, 'COMIDA'), (0, 11, 'SERVIÇO'), (16, 32, 'SERVIÇO')]})
# ...

# %% [markdown]
# #Inicio Adicionando 7 classes para colunas de somatorio das classes

# %%
train_data = df['annotations'].tolist()

# %%
dic_somatorio_classes = {"COMIDA": 0,
                        "SERVIÇO": 1,
                        "AMBIENTE": 2,
                        "LOCALIZAÇÃO": 3,
                        "GERAL": 4,
                        "BEBIDA": 5,
                        "PREÇO": 6}

somatorio_classes = pd.DataFrame(columns=["COMIDA", "SERVIÇO", "AMBIENTE", "LOCALIZAÇÃO", "GERAL", "BEBIDA", "PREÇO"])

# %%
for text, annot in train_data: 
        doc = nlp.make_doc(text) 
        print(text)
        ents = []
        for start, end, label in annot["entities"]: 
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents.append(span)
                df_grafs.loc[len(df_grafs)] = [span.text, label]
                print(span, label)
        doc.ents = ents 
        db.add(doc)

# %% [markdown]
# #Fim Adição das colunas de somatorio de classes

# %%
nlp = spacy.blank("pt") 
db = DocBin()

# %%
train_data = df['annotations'][:305].tolist()
test_data = df['annotations'][100:].tolist()

# %%
df_grafs = pd.DataFrame(columns=['Entidade', 'Classe'])

# %%
for text, annot in train_data: 
        doc = nlp.make_doc(text) 
        print(text)
        ents = []
        for start, end, label in annot["entities"]: 
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents.append(span)
                df_grafs.loc[len(df_grafs)] = [span.text, label]
                print(span, label)
        doc.ents = ents 
        db.add(doc)
# Out:
# Excelente localização, ambiente agradável, lagosta deliciosa, som ao vivo de bom gosto e atendimento excepcional do garçom evandro.
# ambiente AMBIENTE
# som ao vivo AMBIENTE
# lagosta COMIDA
# atendimento SERVIÇO
# garçom evandro SERVIÇO
# localização LOCALIZAÇÃO
# Achei o atendimento um pouco contraditório, a meia noite colocaram música sonolenta para desocuparmos o ambiente mais rápido porém a conta demorou a chegar . Vale muito a pena tomar a cerveja argentina Quilmes (dificilmente encontrada na cidade) e o cardápio é maravilhoso com preço...Mais
# ambiente AMBIENTE
# música GERAL
# cardápio COMIDA
# cerveja argentina Quilmes BEBIDA
# atendimento SERVIÇO
# preço PREÇO
# Estivemos no Coco Bambu dia 21/01/2019 para comemorar nossas bodas de algodão e não podia ser mais perfeito. Agradecer aos colaboradores, em especial ao Mauro e Felipe pela delicadeza e tanta atenção aos detalhes. Jantar maravilhoso, pedimos Salmão com crosta de gergelim, mas o coadjuvante...Mais
# ...

# %%
df_grafs
# Out:
#             Entidade    Classe
# 0           ambiente  AMBIENTE
# 1        som ao vivo  AMBIENTE
# 2            lagosta    COMIDA
# 3        atendimento   SERVIÇO
# 4     garçom evandro   SERVIÇO
# ...              ...       ...
# 1456     arquitetura  AMBIENTE
# 1457           lugar     GERAL
# 1458        recepção  AMBIENTE
# 1459         cozinha  AMBIENTE
# 1460          jantar    COMIDA
#
# [1461 rows x 2 columns]

# %%
df_grafs_unique =  df_grafs.drop_duplicates(subset = "Entidade")
df_grafs_unique
# Out:
#             Entidade       Classe
# 0           ambiente     AMBIENTE
# 1        som ao vivo     AMBIENTE
# 2            lagosta       COMIDA
# 3        atendimento      SERVIÇO
# 4     garçom evandro      SERVIÇO
# ...              ...          ...
# 1443           Nunes      SERVIÇO
# 1450           Apple  ORGANIZAÇÂO
# 1451            Maçã       COMIDA
# 1452           apple       COMIDA
# 1455       atendidos      SERVIÇO
#
# [494 rows x 2 columns]

# %%
df_grafs_unique['Classe'].value_counts()
# Out:
# SERVIÇO        189
# COMIDA         148
# AMBIENTE        42
# LOCALIZAÇÃO     34
# PREÇO           29
# BEBIDA          26
# GERAL           25
# ORGANIZAÇÂO      1
# Name: Classe, dtype: int64

# %%
colors = ["#7B68EE", "#16A085", "#F1C40F", "#1E90FF", "#FF69B4", "#E74C3C", "#CD853F"]
graph_unique = df_grafs_unique['Classe'].value_counts().plot(kind='bar', xlabel='Classes', ylabel='Quantidade', title='Quantidade UNICA de aparições por classe', color=colors)
graph_unique.set_xticklabels(graph_unique.get_xticklabels(), rotation=45, ha="right")
graph_unique
# Out:
# <Axes: title={'center': 'Quantidade UNICA de aparições por classe'}, xlabel='Classes', ylabel='Quantidade'>

# %%
graph_unique = df_grafs_unique['Classe'].value_counts().plot.pie(colors=colors, startangle=90, labels=None, title='Quantidade de aparições UNICAS por classe')
graph_unique.legend(['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(df_grafs_unique['Classe'].value_counts().index, df_grafs_unique['Classe'].value_counts().values/df_grafs_unique['Classe'].value_counts().sum()*100)],title="Classes", bbox_to_anchor=(1,0.5), loc="center left", fontsize=10)
graph_unique
# Out:
# <Axes: title={'center': 'Quantidade de aparições UNICAS por classe'}, ylabel='Classe'>

# %%
df_grafs['Classe'].value_counts()
# Out:
# COMIDA         489
# SERVIÇO        445
# AMBIENTE       184
# GERAL          158
# PREÇO           73
# LOCALIZAÇÃO     57
# BEBIDA          54
# ORGANIZAÇÂO      1
# Name: Classe, dtype: int64

# %%
colors = ["#7B68EE", "#16A085", "#F1C40F", "#1E90FF", "#FF69B4", "#E74C3C", "#CD853F"]
graph = df_grafs['Classe'].value_counts().plot(kind='bar', xlabel='Classes', ylabel='Quantidade', title='Quantidade de aparições por classe', color=colors)
graph.set_xticklabels(graph.get_xticklabels(), rotation=45, ha="right")
graph
# Out:
# <Axes: title={'center': 'Quantidade de aparições por classe'}, xlabel='Classes', ylabel='Quantidade'>

# %%
graph = df_grafs['Classe'].value_counts().plot.pie(colors=colors, startangle=90, labels=None, title='Quantidade de aparições por classe')
graph.legend(['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(df_grafs['Classe'].value_counts().index, df_grafs['Classe'].value_counts().values/df_grafs['Classe'].value_counts().sum()*100)],title="Classes", bbox_to_anchor=(1,0.5), loc="center left", fontsize=10)
graph
# Out:
# <Axes: title={'center': 'Quantidade de aparições por classe'}, ylabel='Classe'>

# %%
pd.set_option('display.max_rows', None)
df_grafs['Entidade'].value_counts()
# Out:
# atendimento                            163
# comida                                 107
# ambiente                                62
# pratos                                  58
# restaurante                             41
# Atendimento                             36
# Comida                                  32
# prato                                   29
# Ambiente                                25
# preço                                   24
# música                                  23
# lugar                                   23
# cardápio                                18
# frutos do mar                           18
# garçons                                 16
# Restaurante                             15
# vista                                   14
# Lugar                                   14
# local                                   14
# Coco Bambu                              14
# camarão                                 13
# serviço                                 12
# ...

# %%
matrix = []
for i in range(7):
    matrix.append([])

# %%
j = 0
for i in df_grafs['Classe'].unique():
  df_generico = df_grafs[df_grafs['Classe'] == i]
  df_generico = df_generico['Entidade'].value_counts().head(10)
  for element, count in df_generico.items():
      matrix[j].append(element)
      print(f'{element} aparece {count} vezes')
  j+=1
# Out:
# ambiente aparece 62 vezes
# Ambiente aparece 25 vezes
# música aparece 22 vezes
# vista aparece 14 vezes
# Música aparece 7 vezes
# mesa aparece 3 vezes
# ambientes aparece 3 vezes
# musica aparece 2 vezes
# espaço para crianças aparece 2 vezes
# luz aparece 2 vezes
# comida aparece 107 vezes
# pratos aparece 58 vezes
# Comida aparece 32 vezes
# prato aparece 29 vezes
# cardápio aparece 18 vezes
# frutos do mar aparece 18 vezes
# camarão aparece 13 vezes
# sobremesa aparece 11 vezes
# porções aparece 7 vezes
# camarão internacional aparece 7 vezes
# atendimento aparece 163 vezes
# Atendimento aparece 36 vezes
# garçons aparece 16 vezes
# serviço aparece 12 vezes
# garçom aparece 9 vezes
# Garçons aparece 7 vezes
# Eduardo aparece 5 vezes
# Marlon aparece 3 vezes
# Charles aparece 3 vezes
# recepção aparece 2 vezes
# localização aparece 8 vezes
# Fortaleza aparece 6 vezes
# estacionamento aparece 5 vezes
# Salvador aparece 3 vezes
# Brasília aparece 3 vezes
# praia aparece 2 vezes
# ...

# %%
j = 0
for i in df_grafs['Classe'].unique():
  print(f'Os elementos que mais apareceram da classe {i} são {matrix[j]}')
  j+=1
# Out:
# Os elementos que mais apareceram da classe AMBIENTE são ['ambiente', 'Ambiente', 'música', 'vista', 'Música', 'mesa', 'ambientes', 'musica', 'espaço para crianças', 'luz']
# Os elementos que mais apareceram da classe COMIDA são ['comida', 'pratos', 'Comida', 'prato', 'cardápio', 'frutos do mar', 'camarão', 'sobremesa', 'porções', 'camarão internacional']
# Os elementos que mais apareceram da classe SERVIÇO são ['atendimento', 'Atendimento', 'garçons', 'serviço', 'garçom', 'Garçons', 'Eduardo', 'Marlon', 'Charles', 'recepção']
# Os elementos que mais apareceram da classe LOCALIZAÇÃO são ['localização', 'Fortaleza', 'estacionamento', 'Salvador', 'Brasília', 'praia', 'São Paulo', 'orla da Capital', 'Cidade de Fortaleza', 'lugar']
# Os elementos que mais apareceram da classe GERAL são ['restaurante', 'lugar', 'Restaurante', 'Lugar', 'Coco Bambu', 'local', 'Local', 'coco bambu', 'restaurantes', 'restaurante Coco Bambu']
# ...

# %%
db.to_disk("./train.spacy")

# %%
nlp2 = spacy.blank("pt") 
db2 = DocBin()

# %%
doc_gold = []
for text, annot in test_data: 
        doc2 = nlp2.make_doc(text) 
        print(text)
        ents2 = []
        for start, end, label in annot["entities"]: 
            span = doc2.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents2.append(span)
                print(span, label)
        doc2.ents = ents2
        entities = [(ent.text, ent.label_) for ent in doc2.ents]
        doc_gold.append(entities)   
        db2.add(doc2)
# Out:
# Sempre bom estar de volta ao Dom Pastel, comida espetacular e atendimento excelente pelo Eduardo e Jonceliano!
# Dom Pastel GERAL
# comida COMIDA
# atendimento SERVIÇO
# Eduardo SERVIÇO
# Jonceliano SERVIÇO
# Lugar agradável, pratos muito bem servidos, muito saborosos! Drinks deliciosos e ainda tem parquinho para as crianças. Recomendo!
# parquinho para as crianças AMBIENTE
# Lugar GERAL
# pratos COMIDA
# Drinks BEBIDA
# Um excelente lugar para conhecer, com uma bela vista do lago sul. Uma refeição maravilhosa, com atendimento de primeira. Comemos frutos do mar, deliciosos. Uma caipirinha de coco incrível. Vale a pena cada centavo. Achamos complicado chegar no restaurante, mesmo com GPS, e também um...Mais
# vista AMBIENTE
# lugar GERAL
# restaurante GERAL
# refeição COMIDA
# frutos do mar COMIDA
# caipirinha de coco BEBIDA
# atendimento SERVIÇO
# cada centavo PREÇO
# ...

# %%
db2.to_disk("./test.spacy")

# %%
! python -m spacy init config config.cfg --lang pt --pipeline ner --optimize efficiency --force
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-29 10:56:44.009586: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-29 10:56:44.009734: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
# !python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./test.spacy --output ./ner_output
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-29 10:56:50.205271: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-29 10:56:50.205345: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
# !spacy evaluate ./ner_output/model-best ./test.spacy
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-10 00:30:48.606965: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-10 00:30:48.607161: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
# !python -m spacy debug data /content/default_config.cfg
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-02-13 23:59:43.921796: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-13 23:59:43.921944: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
# !python -m spacy init fill-config base_config.cfg /content/drive/MyDrive/treino_spacy/config.cfg
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-02-13 23:59:51.535248: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-13 23:59:51.535357: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
test_nlp = spacy.load('/content/ner_output/model-best')

# %%
test_nlp.get_pipe('ner').labels
# Out:
# ('AMBIENTE',
#  'BEBIDA',
#  'COMIDA',
#  'GERAL',
#  'LOCALIZAÇÃO',
#  'ORGANIZAÇÂO',
#  'PREÇO',
#  'SERVIÇO')

# %%
test = 'Gostei muito da visita ao Coco Bambu, a recepção foi ótima, fomos muito bem atendidos. A arquitetura do lugar era linda, da recepção à cozinha, tudo muito organizado'
test2 = 'Ambiente lindo. Garçons atenciosos. Comida fantástica. Bebidas deliciosas. Procure chegar antes das 20 horas, pois tem happy hour com ótimas promoções. Pra quem está em Fortaleza, vale muito a pena vir nesse lugar. Com certeza irá querer repetir.'
test3 = 'Apple Inc. é uma empresa multinacional norte-americana que tem o objetivo de projetar e comercializar produtos eletrônicos'
test4 = 'Maçã em inglês é apple'
test5 = 'Gostei muito da visita ao Coco Bambu, a recepção foi ótima, fomos muito bem atendidos. A arquitetura do lugar era linda, da recepção à cozinha, tudo muito organizado. '
test6 = 'Nossa, que jantar gostoso.'
test7 = 'Nossa, que jantar maravilhoso.'
doc = test_nlp(test2)

# %%
colors = {"COMIDA": "#7B68EE",
          "SERVIÇO": "#16A085",
          "AMBIENTE": "#F1C40F",
          "LOCALIZAÇÃO": "#E74C3C",
          "GERAL": "#1E90FF",
          "BEBIDA": "#CD853F",
          "PREÇO": "#FF69B4"}

spacy.displacy.render(doc, style="ent", jupyter=True, options={"ents": ["COMIDA", "SERVIÇO", "AMBIENTE", "LOCALIZAÇÃO", "GERAL", "BEBIDA", "PREÇO"], "colors": colors})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #F1C40F; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ambiente
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AMBIENTE</span>
# </mark>
#  lindo.
# <mark class="entity" style="background: #16A085; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Garçons
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SERVIÇO</span>
# </mark>
#  atenciosos.
# <mark class="entity" style="background: #7B68EE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Comida
# ...

# %%
doc = test_nlp(test3)
colors = {"ORGANIZAÇÂO": "#999999",
          "COMIDA": "#7B68EE",
          "SERVIÇO": "#16A085",
          "AMBIENTE": "#F1C40F",
          "LOCALIZAÇÃO": "#E74C3C",
          "GERAL": "#1E90FF",
          "BEBIDA": "#CD853F",
          "PREÇO": "#FF69B4"}

spacy.displacy.render(doc, style="ent", jupyter=True, options={"ents": ["ORGANIZAÇÂO","COMIDA", "SERVIÇO", "AMBIENTE", "LOCALIZAÇÃO", "GERAL", "BEBIDA", "PREÇO"], "colors": colors})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #F8F8FF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGANIZAÇÂO</span>
# </mark>
#  Inc. é uma empresa multinacional norte-americana que tem o objetivo de projetar e comercializar produtos eletrônicos</div></span>

# %%
doc = test_nlp(test4)
colors = {"COMIDA": "#7B68EE",
          "SERVIÇO": "#16A085",
          "AMBIENTE": "#F1C40F",
          "LOCALIZAÇÃO": "#E74C3C",
          "GERAL": "#1E90FF",
          "BEBIDA": "#CD853F",
          "PREÇO": "#FF69B4"}

spacy.displacy.render(doc, style="ent", jupyter=True, options={"ents": ["COMIDA", "SERVIÇO", "AMBIENTE", "LOCALIZAÇÃO", "GERAL", "BEBIDA", "PREÇO"], "colors": colors})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7B68EE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maçã
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMIDA</span>
# </mark>
#  em inglês é
# <mark class="entity" style="background: #7B68EE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMIDA</span>
# </mark>
# </div></span>

# %%
doc = test_nlp(test5)
colors = {"COMIDA": "#7B68EE",
          "SERVIÇO": "#16A085",
          "AMBIENTE": "#F1C40F",
          "LOCALIZAÇÃO": "#E74C3C",
          "GERAL": "#1E90FF",
          "BEBIDA": "#CD853F",
          "PREÇO": "#FF69B4"}

spacy.displacy.render(doc, style="ent", jupyter=True, options={"ents": ["COMIDA", "SERVIÇO", "AMBIENTE", "LOCALIZAÇÃO", "GERAL", "BEBIDA", "PREÇO"], "colors": colors})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Gostei muito da visita ao
# <mark class="entity" style="background: #1E90FF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coco Bambu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GERAL</span>
# </mark>
# , a
# <mark class="entity" style="background: #16A085; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recepção
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SERVIÇO</span>
# </mark>
#  foi ótima, fomos muito bem
# <mark class="entity" style="background: #16A085; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     atendidos
# ...

# %%
doc = test_nlp(test6)
colors = {"COMIDA": "#7B68EE",
          "SERVIÇO": "#16A085",
          "AMBIENTE": "#F1C40F",
          "LOCALIZAÇÃO": "#E74C3C",
          "GERAL": "#1E90FF",
          "BEBIDA": "#CD853F",
          "PREÇO": "#FF69B4"}

spacy.displacy.render(doc, style="ent", jupyter=True, options={"ents": ["COMIDA", "SERVIÇO", "AMBIENTE", "LOCALIZAÇÃO", "GERAL", "BEBIDA", "PREÇO"], "colors": colors})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Nossa, que
# <mark class="entity" style="background: #7B68EE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jantar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMIDA</span>
# </mark>
#  gostoso.</div></span>

# %%
doc = test_nlp(test7)
colors = {"COMIDA": "#7B68EE",
          "SERVIÇO": "#16A085",
          "AMBIENTE": "#F1C40F",
          "LOCALIZAÇÃO": "#E74C3C",
          "GERAL": "#1E90FF",
          "BEBIDA": "#CD853F",
          "PREÇO": "#FF69B4"}

spacy.displacy.render(doc, style="ent", jupyter=True, options={"ents": ["COMIDA", "SERVIÇO", "AMBIENTE", "LOCALIZAÇÃO", "GERAL", "BEBIDA", "PREÇO"], "colors": colors})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Nossa, que jantar maravilhoso.</div></span>

# %%
entities = [(ent.text, ent.label_) for ent in doc.ents]
entities
# Out:
# [('Coco Bambu', 'GERAL'),
#  ('recepção', 'SERVIÇO'),
#  ('arquitetura', 'AMBIENTE'),
#  ('lugar', 'GERAL'),
#  ('recepção', 'SERVIÇO'),
#  ('cozinha', 'COMIDA')]

# %%
doc_predicted = []
for text, annot in test_data: 
        predicted = test_nlp(text)
        entities = [(ent.text, ent.label_) for ent in predicted.ents]
        doc_predicted.append(entities)  
print(doc_predicted)
# Out:
# [[('Dom Pastel', 'GERAL'), ('comida', 'COMIDA'), ('atendimento', 'SERVIÇO'), ('Eduardo', 'SERVIÇO'), ('Jonceliano', 'SERVIÇO')], [('Lugar', 'GERAL'), ('pratos', 'COMIDA'), ('Drinks', 'BEBIDA'), ('parquinho para as crianças', 'AMBIENTE')], [('lugar', 'GERAL'), ('vista', 'AMBIENTE'), ('refeição', 'COMIDA'), ('atendimento', 'SERVIÇO'), ('frutos do mar', 'COMIDA'), ('caipirinha de coco', 'BEBIDA'), ('cada centavo', 'PREÇO'), ('restaurante', 'GERAL')], [('Comida', 'COMIDA'), ('ambiente', 'AMBIENTE'), ('atendimento', 'SERVIÇO')], [('Lugar', 'GERAL'), ('mesas', 'AMBIENTE'), ('ambientes', 'AMBIENTE'), ('pratos', 'COMIDA'), ('Comida', 'COMIDA')], [('Comida', 'COMIDA'), ('bebida', 'BEBIDA'), ('ambiente', 'AMBIENTE'), ('Charles', 'SERVIÇO')], [('camarão internacional', 'COMIDA'), ('Atendimento', 'SERVIÇO'), ('comida', 'COMIDA'), ('cerveja', 'BEBIDA')], [('Restaurante', 'GERAL'), ('cardápio', 'COMIDA'), ('camarão', 'COMIDA'), ('pratos', 'COMIDA'), ('serviço', 'SERVIÇO'), ('carta de vinho', 'BEBI
# ...

# %%
doc_gold

# %%
match_count = 0
i = 0
for i in range(len(doc_gold)):
    print(doc_gold[i],doc_predicted[i])

# %% [markdown]
# # Verificando se estão extratificadas

# %%
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt



colors = {"COMIDA": "#7B68EE",
          "SERVIÇO": "#16A085",
          "AMBIENTE": "#F1C40F",
          "LOCALIZAÇÃO": "#E74C3C",
          "GERAL": "#1E90FF",
          "BEBIDA": "#CD853F",
          "PREÇO": "#FF69B4"}

data = df['annotations'].tolist()

kf = KFold(n_splits=5)
j = 1
for train_index, test_index in kf.split(data):
    df_grafs_train = pd.DataFrame(columns=['Entidade', 'Classe'])
    df_grafs_test = pd.DataFrame(columns=['Entidade', 'Classe'])

    nlp = spacy.blank("pt") 
    db = DocBin() 

    nlp2 = spacy.blank("pt") 
    db2 = DocBin()

    train_data = []
    for i in train_index:
        train_data.append(data[i])

    test_data = []
    for i in test_index:
        test_data.append(data[i])

    color = []
    for text, annot in train_data: 
        doc = nlp.make_doc(text) 
        ents = []
        for start, end, label in annot["entities"]: 
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents.append(span)
                df_grafs_train.loc[len(df_grafs_train)] = [span.text, label]
        doc.ents = ents 
        db.add(doc)
    db.to_disk(f"./train{j}.spacy") 

    print(f"Quantidade Absoluta do treino")
    print(df_grafs_train['Classe'].value_counts())

    list_of_class = df_grafs_train['Classe'].value_counts()
    class_order = list_of_class.index.tolist()
    for class_name in class_order:
      color.append(colors.get(class_name))
    
    print(f"Grafico de treino rodada {j}")
    graph = df_grafs_train['Classe'].value_counts().plot(kind='bar', xlabel='Classes', ylabel='Quantidade', title='Quantidade de aparições por classe', color=color)
    graph.set_xticklabels(graph.get_xticklabels(), rotation=45, ha="right")
    plt.show()

    graph = df_grafs_train['Classe'].value_counts().plot.pie(colors=color, startangle=90, labels=None, label="", title=f"Fold - {j} Treino")
    graph.legend(['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(df_grafs_train['Classe'].value_counts().index, df_grafs_train['Classe'].value_counts().values/df_grafs_train['Classe'].value_counts().sum()*100)],title="Classes", bbox_to_anchor=(1,0.5), loc="center left", fontsize=10)
    plt.show()
   
    
    color = []
    for text, annot in test_data: 
        doc2 = nlp2.make_doc(text) 
        ents2 = []
        for start, end, label in annot["entities"]: 
            span = doc2.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents2.append(span)
                df_grafs_test.loc[len(df_grafs_test)] = [span.text, label]
        doc2.ents = ents2 
        db2.add(doc2)
    db2.to_disk(f"./test{j}.spacy") 

    print(f"Quantidade Absoluta do test")
    print(df_grafs_test['Classe'].value_counts())
    list_of_class = df_grafs_test['Classe'].value_counts()

    class_order = list_of_class.index.tolist()
    for class_name in class_order:
      color.append(colors.get(class_name))

    print(f"Grafico de test rodada {j}")
    graph = df_grafs_test['Classe'].value_counts().plot(kind='bar', xlabel='Classes', ylabel='Quantidade', title='Quantidade de aparições por classe', color=color)
    graph.set_xticklabels(graph.get_xticklabels(), rotation=45, ha="right")
    plt.show()

    graph = df_grafs_test['Classe'].value_counts().plot.pie(colors=color, startangle=90, labels=None, label="", title=f"Fold - {j} Teste")
    graph.legend(['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(df_grafs_test['Classe'].value_counts().index, df_grafs_test['Classe'].value_counts().values/df_grafs_test['Classe'].value_counts().sum()*100)],title="Classes", bbox_to_anchor=(1,0.5), loc="center left", fontsize=10)
    plt.show()


    j+=1
# Out:
# Quantidade Absoluta do treino
# COMIDA         636
# SERVIÇO        586
# AMBIENTE       227
# GERAL          196
# PREÇO           91
# LOCALIZAÇÃO     78
# BEBIDA          62
# Name: Classe, dtype: int64
# Grafico de treino rodada 1
# Quantidade Absoluta do test
# COMIDA         160
# SERVIÇO        158
# AMBIENTE        62
# GERAL           46
# BEBIDA          24
# PREÇO           24
# LOCALIZAÇÃO     21
# Name: Classe, dtype: int64
# Grafico de test rodada 1
# Quantidade Absoluta do treino
# COMIDA         620
# SERVIÇO        603
# AMBIENTE       231
# GERAL          180
# LOCALIZAÇÃO     87
# PREÇO           82
# BEBIDA          70
# Name: Classe, dtype: int64
# Grafico de treino rodada 2
# Quantidade Absoluta do test
# COMIDA         176
# SERVIÇO        141
# GERAL           62
# AMBIENTE        58
# PREÇO           33
# BEBIDA          16
# LOCALIZAÇÃO     12
# Name: Classe, dtype: int64
# Grafico de test rodada 2
# Quantidade Absoluta do treino
# COMIDA         646
# ...

# %%
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt

colors = ["#7B68EE",
          "#16A085",
          "#F1C40F",
          "#1E90FF",
          "#FF69B4",
          "#E74C3C",
          "#CD853F"
          ]

classes = ['COMIDA', 'SERVIÇO', 'AMBIENTE', 'GERAL', 'PREÇO', 'LOCALIZAÇÃO', 'BEBIDA']
percentages = [31.87, 29.68, 11.50, 9.63, 4.58, 3.95, 3.44]

graph = plt.pie(percentages, colors=colors, startangle=90, labels=None)

plt.legend(['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(classes, percentages)], title="Classes", bbox_to_anchor=(1,0.5), loc="center left", fontsize=10)
plt.title('Fold de Teste Ideal')
plt.show()

classes = ['COMIDA', 'SERVIÇO', 'AMBIENTE', 'GERAL', 'PREÇO', 'LOCALIZAÇÃO', 'BEBIDA']
percentages = [35.5, 33.1, 12.9, 10.8, 5.1, 4.4, 3.8]

graph = plt.pie(percentages, colors=colors, startangle=90)

plt.legend(['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(classes, percentages)], title="Classes", bbox_to_anchor=(1,0.5), loc="center left", fontsize=10)
plt.title('Fold de Treino Ideal')
plt.show()

# %% [markdown]
# # Fim Extratificadas

# %% [markdown]
# #Tentando extrair e balancear

# %%
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt



colors = {"COMIDA": "#7B68EE",
          "SERVIÇO": "#16A085",
          "AMBIENTE": "#F1C40F",
          "LOCALIZAÇÃO": "#E74C3C",
          "GERAL": "#1E90FF",
          "BEBIDA": "#CD853F",
          "PREÇO": "#FF69B4"}

data = df['annotations'].tolist()
print(data)

kf = KFold(n_splits=5)
j = 1
for train_index, test_index in kf.split(data):
    df_grafs_train = pd.DataFrame(columns=['Entidade', 'Classe'])
    df_grafs_test = pd.DataFrame(columns=['Entidade', 'Classe'])

    nlp = spacy.blank("pt") 
    db = DocBin() 

    nlp2 = spacy.blank("pt") 
    db2 = DocBin()

    train_data = []
    for i in train_index:
        train_data.append(data[i])

    test_data = []
    for i in test_index:
        test_data.append(data[i])

    # print("df_grafs_train: ")
    # print(train_data)
    

    df_train_data = pd.DataFrame(train_data, columns=['Index','Anotação'])
    df_train_data.to_csv(f'/content/drive/MyDrive/treino_spacy/train_data_anotation{j}.csv',index=False)
    df_test_data = pd.DataFrame(test_data, columns=['Index','Anotação'])
    df_test_data.to_csv(f'/content/drive/MyDrive/treino_spacy/test_data_anotation{j}.csv',index=False)

    with open(f'/content/drive/MyDrive/treino_spacy/classes_balanceadas/train_data_anotation{j}_bebida_loc_preco_geral_ambiente.csv', encoding="utf-8") as f:
      df_train_data = pd.read_csv(f)
    # print(df_train_data)
    df_train_data['Anotação'] = df_train_data['Anotação'].apply(ast.literal_eval)

    df_train_data["Index"] = df_train_data[["Index","Anotação"]].apply(tuple, axis=1)
    # print(df_train_data)

    df_train_data = df_train_data['Index'].tolist()
    # print(df_train_data)

    

    with open(f'/content/drive/MyDrive/treino_spacy/classes_balanceadas/test_data_anotation{j}_bebida_loc_preco_geral_ambiente.csv', encoding="utf-8") as f:
      df_test_data = pd.read_csv(f)
    # print(df_test_data)
    df_test_data['Anotação'] = df_test_data['Anotação'].apply(ast.literal_eval)

    df_test_data["Index"] = df_test_data[["Index","Anotação"]].apply(tuple, axis=1)
    # print(df_test_data)

    #print("df_grafs_test: ")
    # print(test_data)
    

    df_test_data = df_test_data['Index'].tolist()
    # print(df_test_data)

    train_data = df_train_data
    test_data = df_test_data

    color = []
    for text, annot in train_data: 
        doc = nlp.make_doc(text) 
        ents = []
        for start, end, label in annot["entities"]: 
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents.append(span)
                df_grafs_train.loc[len(df_grafs_train)] = [span.text, label]
        doc.ents = ents 
        db.add(doc)
    db.to_disk(f"./train{j}.spacy") 

    print(f"Quantidade Absoluta do treino")
    print(df_grafs_train['Classe'].value_counts())

    list_of_class = df_grafs_train['Classe'].value_counts()
    class_order = list_of_class.index.tolist()
    for class_name in class_order:
      color.append(colors.get(class_name))
    
    print(f"Grafico de treino rodada {j}")
    graph = df_grafs_train['Classe'].value_counts().plot(kind='bar', xlabel='Classes', ylabel='Quantidade', title='Quantidade de aparições por classe', color=color)
    graph.set_xticklabels(graph.get_xticklabels(), rotation=45, ha="right")
    plt.show()

    graph = df_grafs_train['Classe'].value_counts().plot.pie(colors=color, startangle=90, labels=None, label="", title=f"Fold - {j} Treino")
    graph.legend(['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(df_grafs_train['Classe'].value_counts().index, df_grafs_train['Classe'].value_counts().values/df_grafs_train['Classe'].value_counts().sum()*100)],title="Classes", bbox_to_anchor=(1,0.5), loc="center left", fontsize=10)
    plt.show()
   
    
    color = []
    for text, annot in test_data: 
        doc2 = nlp2.make_doc(text) 
        ents2 = []
        for start, end, label in annot["entities"]: 
            span = doc2.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents2.append(span)
                df_grafs_test.loc[len(df_grafs_test)] = [span.text, label]
        doc2.ents = ents2 
        db2.add(doc2)
    db2.to_disk(f"./test{j}.spacy") 

    print(f"Quantidade Absoluta do test")
    print(df_grafs_test['Classe'].value_counts())
    list_of_class = df_grafs_test['Classe'].value_counts()

    class_order = list_of_class.index.tolist()
    for class_name in class_order:
      color.append(colors.get(class_name))

    print(f"Grafico de test rodada {j}")
    graph = df_grafs_test['Classe'].value_counts().plot(kind='bar', xlabel='Classes', ylabel='Quantidade', title='Quantidade de aparições por classe', color=color)
    graph.set_xticklabels(graph.get_xticklabels(), rotation=45, ha="right")
    plt.show()

    graph = df_grafs_test['Classe'].value_counts().plot.pie(colors=color, startangle=90, labels=None, label="", title=f"Fold - {j} Teste")
    graph.legend(['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(df_grafs_test['Classe'].value_counts().index, df_grafs_test['Classe'].value_counts().values/df_grafs_test['Classe'].value_counts().sum()*100)],title="Classes", bbox_to_anchor=(1,0.5), loc="center left", fontsize=10)
    plt.show()


    j+=1
# Out:
# [('Excelente localização, ambiente agradável, lagosta deliciosa, som ao vivo de bom gosto e atendimento excepcional do garçom evandro.', {'entities': [(23, 31, 'AMBIENTE'), (62, 73, 'AMBIENTE'), (43, 50, 'COMIDA'), (89, 100, 'SERVIÇO'), (116, 130, 'SERVIÇO'), (10, 21, 'LOCALIZAÇÃO')]}), ('Achei o atendimento um pouco contraditório, a meia noite colocaram música sonolenta para desocuparmos o ambiente mais rápido porém a conta demorou a chegar . Vale muito a pena tomar a cerveja argentina Quilmes (dificilmente encontrada na cidade) e o cardápio é maravilhoso com preço...Mais', {'entities': [(104, 112, 'AMBIENTE'), (67, 73, 'GERAL'), (250, 258, 'COMIDA'), (184, 209, 'BEBIDA'), (8, 19, 'SERVIÇO'), (277, 282, 'PREÇO')]}), ('Estivemos no Coco Bambu dia 21/01/2019 para comemorar nossas bodas de algodão e não podia ser mais perfeito. Agradecer aos colaboradores, em especial ao Mauro e Felipe pela delicadeza e tanta atenção aos detalhes. Jantar maravilhoso, pedimos Salmão com crosta de gergel
# ...

# %% [markdown]
# #Fim Tentando extrair e balancear

# %% [markdown]
# # Tentando 5 folds

# %%
from sklearn.model_selection import KFold

data = df['annotations'].tolist()

annoteded_list = [[],[],[],[],[],[]]
annoteded_list2 = [[],[],[],[],[],[]]
tests_text = [[],[],[],[],[],[]]

kf = KFold(n_splits=5)
j = 1
for train_index, test_index in kf.split(data):

    nlp = spacy.blank("pt") 
    db = DocBin() 

    nlp2 = spacy.blank("pt") 
    db2 = DocBin()

    train_data = []
    for i in train_index:
        train_data.append(data[i])

    test_data = []
    for i in test_index:
        test_data.append(data[i])

    tests_text[j].append(test_data)
    for text, annot in train_data: 
        doc = nlp.make_doc(text) 
        ents = []
        for start, end, label in annot["entities"]: 
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents.append(span)
        doc.ents = ents 
        db.add(doc)
    db.to_disk(f"./train{j}.spacy") 
    for text, annot in test_data: 
        doc2 = nlp2.make_doc(text) 
        ents2 = []
        ents_label = []
        for start, end, label in annot["entities"]: 
            span = doc2.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents2.append(span)
                ents_label.append(span)
                ents_label.append(label)
        doc2.ents = ents2 
        annoteded_list[j].append(ents_label)

        annoteded_list2[j].append(doc2)

        db2.add(doc2)
    db2.to_disk(f"./test{j}.spacy") 
    j+=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-0813b0929370> in <module>
#      27     tests_text[j].append(test_data)
#      28     for text, annot in train_data:
# ---> 29         doc = nlp.make_doc(text)
#      30         ents = []
#      31         for start, end, label in annot["entities"]:
#
# /usr/local/lib/python3.9/dist-packages/spacy/language.py in make_doc(self, text)
#    1080                 Errors.E088.format(length=len(text), max_length=self.max_length)
#    1081             )
# -> 1082         return self.tokenizer(text)
#    1083
#    1084     def _ensure_doc(self, doc_like: Union[str, Doc, bytes]) -> Doc:
#
# /usr/local/lib/python3.9/dist-packages/spacy/tokenizer.pyx in spacy.tokenizer.Tokenizer.__call__()
#
# /usr/local/lib/python3.9/dist-packages/spacy/tokenizer.pyx in spacy.tokenizer.Tokenizer._tokenize_affixes()
#
# ...

# %%
annoteded_list[1][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f457fe0abaa5> in <module>
# ----> 1 annoteded_list[1][0]
#
# NameError: name 'annoteded_list' is not defined

# %%
# !python -m spacy train config.cfg --paths.train ./train1.spacy --paths.dev ./test1.spacy --output ./ner_output1
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-18 21:17:37.719167: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-18 21:17:37.719296: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %% [markdown]
# #Tentando achar os erros, falsos positivos

# %%
tests_text[1][0]

# %%
model_output_list = [[],[],[],[],[],[]]


for j in range(1,6):
  test_nlp = spacy.load(f'/content/ner_output{j}/model-best')

  for text, annot in tests_text[j][0]:
    print(text)
    
    doc = test_nlp(text)
    
    # ents_label = []

    # for ent in doc.ents : 
      
    #   ents_label.append(ent.text)
    #   print(ent.text)
    #   ents_label.append(ent.label_)
    #   print(ent.label_)
    #   ents_label.append(ent.start_char)
    #   print(ent.start_char)
    #   ents_label.append(ent.end_char)
    #   print(ent.end_char)
            
    # model_output_list[j].append(ents_label)

    model_output_list[j].append(test_nlp(text))
    
  j += 1

model_output_list

# %%
# annoteded_list2
# model_output_list
true_positives = []
print(annoteded_list2)
for i in range(1,6):
  j = 0;
  for doc_annoteded in annoteded_list2[i]:
    doc_from_output = model_output_list[i][j]
    #for doc_annoteded in model_output_list[i]:
    # print(text)
    
    # doc = test_nlp(text)
    
    # ents_label = []

    for ent_annoteded in doc_annoteded.ents:
      for ent_from_output in doc_from_output.ents:  
        print("Ent from output: ", ent_from_output.text, ent_from_output.label_, ent_from_output.start_char, ent_from_output.end_char)
        if(ent_from_output.text == ent_annoteded.text and ent_from_output.label_ == ent_annoteded.label_ and ent_from_output.start_char == ent_annoteded.start_char and ent_from_output.end_char == ent_annoteded.end_char):
          print("Achei o igual")
          true_positives.append(ent_from_output.text)
      print("Ent anoteded: ", ent_annoteded.text, ent_annoteded.label_, ent_annoteded.start_char, ent_annoteded.end_char)
    j += 1
true_positives
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Ent from output:  pratos COMIDA 30 36
# Achei o igual
# Ent from output:  Local GERAL 49 54
# Ent from output:  comida COMIDA 72 78
# Ent from output:  promoções PREÇO 109 118
# Ent from output:  prato COMIDA 123 128
# Ent anoteded:  pratos COMIDA 30 36
# Ent from output:  pratos COMIDA 30 36
# Ent from output:  Local GERAL 49 54
# Achei o igual
# Ent from output:  comida COMIDA 72 78
# Ent from output:  promoções PREÇO 109 118
# Ent from output:  prato COMIDA 123 128
# Ent anoteded:  Local GERAL 49 54
# Ent from output:  pratos COMIDA 30 36
# Ent from output:  Local GERAL 49 54
# Ent from output:  comida COMIDA 72 78
# Achei o igual
# Ent from output:  promoções PREÇO 109 118
# Ent from output:  prato COMIDA 123 128
# Ent anoteded:  comida COMIDA 72 78
# Ent from output:  pratos COMIDA 30 36
# Ent from output:  Local GERAL 49 54
# Ent from output:  comida COMIDA 72 78
# Ent from output:  promoções PREÇO 109 118
# ...

# %% [markdown]
# #Fim de achar os erros, falso positivos

# %%
# !spacy evaluate ./ner_output1/model-best ./test1.spacy >result_output1.txt
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-18 21:29:33.941087: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-18 21:29:33.941185: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
# !python -m spacy train config.cfg --paths.train ./train2.spacy --paths.dev ./test2.spacy --output ./ner_output2
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-18 21:29:39.972317: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-18 21:29:39.972436: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
# !spacy evaluate ./ner_output2/model-best ./test2.spacy >result_output2.txt
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-18 21:34:37.007205: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-18 21:34:37.007331: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
# !python -m spacy train config.cfg --paths.train ./train3.spacy --paths.dev ./test3.spacy --output ./ner_output3
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-18 21:34:42.969344: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-18 21:34:42.969471: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
# !spacy evaluate ./ner_output3/model-best ./test3.spacy >result_output3.txt
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-18 21:43:02.479378: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-18 21:43:02.479552: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
# !python -m spacy train config.cfg --paths.train ./train4.spacy --paths.dev ./test4.spacy --output ./ner_output4
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-18 21:43:08.920515: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-18 21:43:08.920638: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
# !spacy evaluate ./ner_output4/model-best ./test4.spacy >result_output4.txt
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-18 21:54:18.639702: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-18 21:54:18.639820: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
# !python -m spacy train config.cfg --paths.train ./train5.spacy --paths.dev ./test5.spacy --output ./ner_output5
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-18 21:54:25.791524: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-18 21:54:25.791636: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
# !spacy evaluate ./ner_output5/model-best ./test5.spacy >result_output5.txt
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-18 22:07:19.584977: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-18 22:07:19.585128: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
tudo = []

for i in range(1,6):

  f = open(f"/content/result_output{i}.txt", "r")
  f = f.read()
  f = f.split()

  tudo.append(f)

classesPRF = [['SERVIÇO',[0,0,0]], ['COMIDA',[0,0,0]], ['AMBIENTE',[0,0,0]], ['LOCALIZAÇÃO',[0,0,0]], ['GERAL',[0,0,0]], ['BEBIDA',[0,0,0]], ['PREÇO',[0,0,0]]]

for fold in tudo:
  for palavraFold in range(len(fold)):
    for classe in classesPRF:
      if fold[palavraFold] == classe[0]:
        classe[1][0] += float(fold[palavraFold+1])
        classe[1][1] += float(fold[palavraFold+2])
        classe[1][2] += float(fold[palavraFold+3])


print(f"Serviço:     p:{classesPRF[0][1][0]/5:.2f} r:{classesPRF[0][1][1]/5:.2f} f:{classesPRF[0][1][2]/5:.2f}")
print(f"Comida:      p:{classesPRF[1][1][0]/5:.2f} r:{classesPRF[1][1][1]/5:.2f} f:{classesPRF[1][1][2]/5:.2f}")
print(f"Ambiente:    p:{classesPRF[2][1][0]/5:.2f} r:{classesPRF[2][1][1]/5:.2f} f:{classesPRF[2][1][2]/5:.2f}")
print(f"Localização: p:{classesPRF[3][1][0]/5:.2f} r:{classesPRF[3][1][1]/5:.2f} f:{classesPRF[3][1][2]/5:.2f}")
print(f"Geral:       p:{classesPRF[4][1][0]/5:.2f} r:{classesPRF[4][1][1]/5:.2f} f:{classesPRF[4][1][2]/5:.2f}")
print(f"Bebida:      p:{classesPRF[5][1][0]/5:.2f} r:{classesPRF[5][1][1]/5:.2f} f:{classesPRF[5][1][2]/5:.2f}")
print(f"Preço:       p:{classesPRF[6][1][0]/5:.2f} r:{classesPRF[6][1][1]/5:.2f} f:{classesPRF[6][1][2]/5:.2f}")
# Out:
# Serviço:     p:87.14 r:85.61 f:86.33
# Comida:      p:84.52 r:82.69 f:83.56
# Ambiente:    p:83.79 r:82.69 f:83.03
# Localização: p:73.49 r:60.79 f:66.13
# Geral:       p:89.02 r:93.39 f:91.11
# Bebida:      p:89.91 r:80.13 f:84.60
# Preço:       p:73.94 r:69.56 f:71.48

# %% [markdown]
# Estudo da biblioteca de extração extratificada

# %%
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit
X = np.array([["COMIDA", "SERVIÇO"], ["BEBIDA", "GERAL"], ["COMIDA", "SERVIÇO"], ["BEBIDA", "GERAL"], ["COMIDA", "SERVIÇO"], ["BEBIDA", "GERAL"]])
print(X)
y = np.array(["PREÇO","LOCALIZAÇÂO", "LOCALIZAÇÂO", "COMIDA", "PREÇO", "COMIDA"])
print(y)
sss = StratifiedShuffleSplit(n_splits=5, test_size=0.5, random_state=0)
sss.get_n_splits(X, y)
# Out:
# [['COMIDA' 'SERVIÇO']
#  ['BEBIDA' 'GERAL']
#  ['COMIDA' 'SERVIÇO']
#  ['BEBIDA' 'GERAL']
#  ['COMIDA' 'SERVIÇO']
#  ['BEBIDA' 'GERAL']]
# ['PREÇO' 'LOCALIZAÇÂO' 'LOCALIZAÇÂO' 'COMIDA' 'PREÇO' 'COMIDA']
# 5

# %%
print(sss)
StratifiedShuffleSplit(n_splits=5, random_state=0)
for train_index, test_index in sss.split(X, y):
  print(train_index, test_index)
for i, (train_index, test_index) in enumerate(sss.split(X, y)):
  print(f"Fold {i}:")
  print(f"  Train: index={train_index}")
  print(f"  Test:  index={test_index}")
# Out:
# StratifiedShuffleSplit(n_splits=5, random_state=0, test_size=0.5,
#             train_size=None)
# [0 1 5] [3 4 2]
# [2 3 4] [1 0 5]
# [1 5 4] [3 0 2]
# [4 3 1] [0 2 5]
# [2 0 3] [4 1 5]
# Fold 0:
#   Train: index=[0 1 5]
#   Test:  index=[3 4 2]
# Fold 1:
#   Train: index=[2 3 4]
#   Test:  index=[1 0 5]
# Fold 2:
#   Train: index=[1 5 4]
#   Test:  index=[3 0 2]
# Fold 3:
#   Train: index=[4 3 1]
#   Test:  index=[0 2 5]
# Fold 4:
#   Train: index=[2 0 3]
#   Test:  index=[4 1 5]
